# %% [markdown]
# # Data Cleaning: NYC 311 Service Requests
#
# This notebook downloads and cleans the 2024 NYC 311 service request data. We start by fetching the raw data from the Socrata API, then apply cleaning steps to prepare it for analysis.

# %% [markdown]
# ## Installing required packages
#
# The next cell installs the `python-dotenv` package, which allows us to load environment variables from the `.env` file. This keeps our API token secure and out of the code. It also loads some other required packages for the notebook to run

# %%
#!python3 -m pip install python-dotenv
#!python3 -m pip install pandas 
#!python3 -m pip install seaborn matplotlib plotly scikit-learn pyarrow
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.2.1
# Requirement already satisfied: pandas in /Users/sagorika/Library/Python/3.14/lib/python/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in /Users/sagorika/Library/Python/3.14/lib/python/site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sagorika/Library/Python/3.14/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/sagorika/Library/Python/3.14/lib/python/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sagorika/Library/Python/3.14/lib/python/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/sagorika/Library/Python/3.14/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: seaborn in /Users/sagorika/Library/Python/3.14/lib/python/site-packages (0.13.2)
# Requirement already satisfied: matplotlib in /Users/sagorika/Library/Python/3.14/lib/python/site-packages (3.10.7)
# Requirement already satisfied: plotly in /Users/sagorika/Library/Python/3.14/lib/python/site-packages (6.5.0)
# Requirement already satisfied: scikit-learn in /Users/sagorika/Library/Python/3.14/lib/python/site-packages (1.7.2)
# Requirement already satisfied: pyarrow in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (22.0.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/sagorika/Library/Python/3.14/lib/python/site-packages (from seaborn) (2.3.5)
# Requirement already satisfied: pandas>=1.2 in /Users/sagorika/Library/Python/3.14/lib/python/site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/sagorika/Library/Python/3.14/lib/python/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/sagorika/Library/Python/3.14/lib/python/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/sagorika/Library/Python/3.14/lib/python/site-packages (from matplotlib) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/sagorika/Library/Python/3.14/lib/python/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/sagorika/Library/Python/3.14/lib/python/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/sagorika/Library/Python/3.14/lib/python/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/sagorika/Library/Python/3.14/lib/python/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/sagorika/Library/Python/3.14/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: narwhals>=1.15.1 in /Users/sagorika/Library/Python/3.14/lib/python/site-packages (from plotly) (2.13.0)
# Requirement already satisfied: scipy>=1.8.0 in /Users/sagorika/Library/Python/3.14/lib/python/site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /Users/sagorika/Library/Python/3.14/lib/python/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/sagorika/Library/Python/3.14/lib/python/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/sagorika/Library/Python/3.14/lib/python/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sagorika/Library/Python/3.14/lib/python/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/sagorika/Library/Python/3.14/lib/python/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %% [markdown]
# ## Fetching and saving raw data
#
# The next cell loads the environment variables, imports the data fetching function, and retrieves all 2024 NYC 311 records from the Socrata API. It handles pagination automatically and prints summary information about the fetched data. Finally, it saves the raw dataset as a parquet file for later cleaning steps.

# %%
# importing fetch function for NYC 311
from pathlib import Path
import os
import sys

# loading environment variables
try:
    from dotenv import load_dotenv
    load_dotenv(Path('..') / '.env')
except ImportError:
    print("Warning: python-dotenv not installed. Install with: pip install python-dotenv")
    print("Continuing without .env file support...")

PROJECT_ROOT = Path('..').resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from src.nyc311_api import fetch_nyc311_data

# reading Socrata app token from environment variable
APP_TOKEN = os.getenv("SOCRATA_APP_TOKEN")
if not APP_TOKEN:
    print("Note: SOCRATA_APP_TOKEN not found in environment. API calls may be slower.")

# fetching 2024 data
df_raw = fetch_nyc311_data(
    app_token=APP_TOKEN,
    limit=25000,  
    year=2024,
)

print(f"DataFrame shape: {df_raw.shape}")
print(f"Columns: {list(df_raw.columns)}")
print(f"\nFirst few rows:")
print(df_raw.head().to_string())

raw_dir = PROJECT_ROOT / 'data' / 'raw'
raw_dir.mkdir(parents=True, exist_ok=True)

raw_path = raw_dir / 'nyc311_2024_raw.parquet'
df_raw.to_parquet(raw_path, index=False)

print(f"\nRaw data saved to: {raw_path}")
raw_path
# Out:
# Starting data fetch for year 2024...
# Using limit of 25,000 rows per request.
# App token detected. Using authenticated requests.
#
# Fetching page 1 (offset 0)... Received 25,000 rows (total so far: 25,000)
# Fetching page 2 (offset 25,000)... Received 25,000 rows (total so far: 50,000)
# Fetching page 3 (offset 50,000)... Received 25,000 rows (total so far: 75,000)
# Fetching page 4 (offset 75,000)... Received 25,000 rows (total so far: 100,000)
# Fetching page 5 (offset 100,000)... Received 25,000 rows (total so far: 125,000)
# Fetching page 6 (offset 125,000)... Received 25,000 rows (total so far: 150,000)
# Fetching page 7 (offset 150,000)... Received 25,000 rows (total so far: 175,000)
# Fetching page 8 (offset 175,000)... Received 25,000 rows (total so far: 200,000)
# Fetching page 9 (offset 200,000)... Received 25,000 rows (total so far: 225,000)
# Fetching page 10 (offset 225,000)... Received 25,000 rows (total so far: 250,000)
# Fetching page 11 (offset 250,000)... Received 25,000 rows (total so far: 275,000)
# Fetching page 12 (offset 275,000)... Received 25,000 rows (total so far: 300,000)
# Fetching page 13 (offset 300,000)... Received 25,000 rows (total so far: 325,000)
# Fetching page 14 (offset 325,000)... Received 25,000 rows (total so far: 350,000)
# Fetching page 15 (offset 350,000)... Received 25,000 rows (total so far: 375,000)
# Fetching page 16 (offset 375,000)... Received 25,000 rows (total so far: 400,000)
# Fetching page 17 (offset 400,000)... Received 25,000 rows (total so far: 425,000)
# Fetching page 18 (offset 425,000)... Received 25,000 rows (total so far: 450,000)
# Fetching page 19 (offset 450,000)... Received 25,000 rows (total so far: 475,000)
# Fetching page 20 (offset 475,000)... Received 25,000 rows (total so far: 500,000)
# Fetching page 21 (offset 500,000)... Received 25,000 rows (total so far: 525,000)
# Fetching page 22 (offset 525,000)... Received 25,000 rows (total so far: 550,000)
# Fetching page 23 (offset 550,000)... Received 25,000 rows (total so far: 575,000)
# Fetching page 24 (offset 575,000)... Received 25,000 rows (total so far: 600,000)
# Fetching page 25 (offset 600,000)... Received 25,000 rows (total so far: 625,000)
# Fetching page 26 (offset 625,000)... Received 25,000 rows (total so far: 650,000)
# Fetching page 27 (offset 650,000)... Received 25,000 rows (total so far: 675,000)
# Fetching page 28 (offset 675,000)... Received 25,000 rows (total so far: 700,000)
# Fetching page 29 (offset 700,000)... Received 25,000 rows (total so far: 725,000)
# Fetching page 30 (offset 725,000)... Received 25,000 rows (total so far: 750,000)
# Fetching page 31 (offset 750,000)... Received 25,000 rows (total so far: 775,000)
# Fetching page 32 (offset 775,000)... Received 25,000 rows (total so far: 800,000)
# Fetching page 33 (offset 800,000)... Received 25,000 rows (total so far: 825,000)
# Fetching page 34 (offset 825,000)... Received 25,000 rows (total so far: 850,000)
# Fetching page 35 (offset 850,000)... Received 25,000 rows (total so far: 875,000)
# Fetching page 36 (offset 875,000)... Received 25,000 rows (total so far: 900,000)
# Fetching page 37 (offset 900,000)... Received 25,000 rows (total so far: 925,000)
# Fetching page 38 (offset 925,000)... Received 25,000 rows (total so far: 950,000)
# Fetching page 39 (offset 950,000)... Received 25,000 rows (total so far: 975,000)
# Fetching page 40 (offset 975,000)... Received 25,000 rows (total so far: 1,000,000)
# Fetching page 41 (offset 1,000,000)... Received 25,000 rows (total so far: 1,025,000)
# Fetching page 42 (offset 1,025,000)... Received 25,000 rows (total so far: 1,050,000)
# Fetching page 43 (offset 1,050,000)... Received 25,000 rows (total so far: 1,075,000)
# Fetching page 44 (offset 1,075,000)... Received 25,000 rows (total so far: 1,100,000)
# Fetching page 45 (offset 1,100,000)... Received 25,000 rows (total so far: 1,125,000)
# Fetching page 46 (offset 1,125,000)... Received 25,000 rows (total so far: 1,150,000)
# Fetching page 47 (offset 1,150,000)... Received 25,000 rows (total so far: 1,175,000)
# Fetching page 48 (offset 1,175,000)... Received 25,000 rows (total so far: 1,200,000)
# Fetching page 49 (offset 1,200,000)... Received 25,000 rows (total so far: 1,225,000)
# Fetching page 50 (offset 1,225,000)... Received 25,000 rows (total so far: 1,250,000)
# Fetching page 51 (offset 1,250,000)... Received 25,000 rows (total so far: 1,275,000)
# Fetching page 52 (offset 1,275,000)... Received 25,000 rows (total so far: 1,300,000)
# Fetching page 53 (offset 1,300,000)... Received 25,000 rows (total so far: 1,325,000)
# Fetching page 54 (offset 1,325,000)... Received 25,000 rows (total so far: 1,350,000)
# Fetching page 55 (offset 1,350,000)... Received 25,000 rows (total so far: 1,375,000)
# Fetching page 56 (offset 1,375,000)... Received 25,000 rows (total so far: 1,400,000)
# Fetching page 57 (offset 1,400,000)... Received 25,000 rows (total so far: 1,425,000)
# Fetching page 58 (offset 1,425,000)... Received 25,000 rows (total so far: 1,450,000)
# Fetching page 59 (offset 1,450,000)... Received 25,000 rows (total so far: 1,475,000)
# Fetching page 60 (offset 1,475,000)... Received 25,000 rows (total so far: 1,500,000)
# Fetching page 61 (offset 1,500,000)... Received 25,000 rows (total so far: 1,525,000)
# Fetching page 62 (offset 1,525,000)... Received 25,000 rows (total so far: 1,550,000)
# Fetching page 63 (offset 1,550,000)... Received 25,000 rows (total so far: 1,575,000)
# Fetching page 64 (offset 1,575,000)... Received 25,000 rows (total so far: 1,600,000)
# Fetching page 65 (offset 1,600,000)... Received 25,000 rows (total so far: 1,625,000)
# Fetching page 66 (offset 1,625,000)... Received 25,000 rows (total so far: 1,650,000)
# Fetching page 67 (offset 1,650,000)... Received 25,000 rows (total so far: 1,675,000)
# Fetching page 68 (offset 1,675,000)... Received 25,000 rows (total so far: 1,700,000)
# Fetching page 69 (offset 1,700,000)... Received 25,000 rows (total so far: 1,725,000)
# Fetching page 70 (offset 1,725,000)... Received 25,000 rows (total so far: 1,750,000)
# Fetching page 71 (offset 1,750,000)... Received 25,000 rows (total so far: 1,775,000)
# Fetching page 72 (offset 1,775,000)... Received 25,000 rows (total so far: 1,800,000)
# Fetching page 73 (offset 1,800,000)... Received 25,000 rows (total so far: 1,825,000)
# Fetching page 74 (offset 1,825,000)... Received 25,000 rows (total so far: 1,850,000)
# Fetching page 75 (offset 1,850,000)... Received 25,000 rows (total so far: 1,875,000)
# Fetching page 76 (offset 1,875,000)... Received 25,000 rows (total so far: 1,900,000)
# Fetching page 77 (offset 1,900,000)... Received 25,000 rows (total so far: 1,925,000)
# Fetching page 78 (offset 1,925,000)... Received 25,000 rows (total so far: 1,950,000)
# Fetching page 79 (offset 1,950,000)... Received 25,000 rows (total so far: 1,975,000)
# Fetching page 80 (offset 1,975,000)... Received 25,000 rows (total so far: 2,000,000)
# Fetching page 81 (offset 2,000,000)... Received 25,000 rows (total so far: 2,025,000)
# Fetching page 82 (offset 2,025,000)... Received 25,000 rows (total so far: 2,050,000)
# Fetching page 83 (offset 2,050,000)... Received 25,000 rows (total so far: 2,075,000)
# Fetching page 84 (offset 2,075,000)... Received 25,000 rows (total so far: 2,100,000)
# Fetching page 85 (offset 2,100,000)... Received 25,000 rows (total so far: 2,125,000)
# Fetching page 86 (offset 2,125,000)... Request timed out. Retrying in 2 seconds... (attempt 1/3)
# Received 25,000 rows (total so far: 2,150,000)
# Fetching page 87 (offset 2,150,000)... Received 25,000 rows (total so far: 2,175,000)
# Fetching page 88 (offset 2,175,000)... Received 25,000 rows (total so far: 2,200,000)
# Fetching page 89 (offset 2,200,000)... Received 25,000 rows (total so far: 2,225,000)
# Fetching page 90 (offset 2,225,000)... Received 25,000 rows (total so far: 2,250,000)
# Fetching page 91 (offset 2,250,000)... Received 25,000 rows (total so far: 2,275,000)
# Fetching page 92 (offset 2,275,000)... Received 25,000 rows (total so far: 2,300,000)
# Fetching page 93 (offset 2,300,000)... Received 25,000 rows (total so far: 2,325,000)
# Fetching page 94 (offset 2,325,000)... Received 25,000 rows (total so far: 2,350,000)
# Fetching page 95 (offset 2,350,000)... Received 25,000 rows (total so far: 2,375,000)
# Fetching page 96 (offset 2,375,000)... Received 25,000 rows (total so far: 2,400,000)
# Fetching page 97 (offset 2,400,000)... Received 25,000 rows (total so far: 2,425,000)
# Fetching page 98 (offset 2,425,000)... Received 25,000 rows (total so far: 2,450,000)
# Fetching page 99 (offset 2,450,000)... Received 25,000 rows (total so far: 2,475,000)
# Fetching page 100 (offset 2,475,000)... Received 25,000 rows (total so far: 2,500,000)
# Fetching page 101 (offset 2,500,000)... Received 25,000 rows (total so far: 2,525,000)
# Fetching page 102 (offset 2,525,000)... Received 25,000 rows (total so far: 2,550,000)
# Fetching page 103 (offset 2,550,000)... Received 25,000 rows (total so far: 2,575,000)
# Fetching page 104 (offset 2,575,000)... Received 25,000 rows (total so far: 2,600,000)
# Fetching page 105 (offset 2,600,000)... Received 25,000 rows (total so far: 2,625,000)
# Fetching page 106 (offset 2,625,000)... Received 25,000 rows (total so far: 2,650,000)
# Fetching page 107 (offset 2,650,000)... Received 25,000 rows (total so far: 2,675,000)
# Fetching page 108 (offset 2,675,000)... Received 25,000 rows (total so far: 2,700,000)
# Fetching page 109 (offset 2,700,000)... Received 25,000 rows (total so far: 2,725,000)
# Fetching page 110 (offset 2,725,000)... Received 25,000 rows (total so far: 2,750,000)
# Fetching page 111 (offset 2,750,000)... Received 25,000 rows (total so far: 2,775,000)
# Fetching page 112 (offset 2,775,000)... Received 25,000 rows (total so far: 2,800,000)
# Fetching page 113 (offset 2,800,000)... Received 25,000 rows (total so far: 2,825,000)
# Fetching page 114 (offset 2,825,000)... Received 25,000 rows (total so far: 2,850,000)
# Fetching page 115 (offset 2,850,000)... Received 25,000 rows (total so far: 2,875,000)
# Fetching page 116 (offset 2,875,000)... Received 25,000 rows (total so far: 2,900,000)
# Fetching page 117 (offset 2,900,000)... Received 25,000 rows (total so far: 2,925,000)
# Fetching page 118 (offset 2,925,000)... Received 25,000 rows (total so far: 2,950,000)
# Fetching page 119 (offset 2,950,000)... Received 25,000 rows (total so far: 2,975,000)
# Fetching page 120 (offset 2,975,000)... Received 25,000 rows (total so far: 3,000,000)
# Fetching page 121 (offset 3,000,000)... Received 25,000 rows (total so far: 3,025,000)
# Fetching page 122 (offset 3,025,000)... Received 25,000 rows (total so far: 3,050,000)
# Fetching page 123 (offset 3,050,000)... Received 25,000 rows (total so far: 3,075,000)
# Fetching page 124 (offset 3,075,000)... Received 25,000 rows (total so far: 3,100,000)
# Fetching page 125 (offset 3,100,000)... Received 25,000 rows (total so far: 3,125,000)
# Fetching page 126 (offset 3,125,000)... Received 25,000 rows (total so far: 3,150,000)
# Fetching page 127 (offset 3,150,000)... Received 25,000 rows (total so far: 3,175,000)
# Fetching page 128 (offset 3,175,000)... Received 25,000 rows (total so far: 3,200,000)
# Fetching page 129 (offset 3,200,000)... Received 25,000 rows (total so far: 3,225,000)
# Fetching page 130 (offset 3,225,000)... Received 25,000 rows (total so far: 3,250,000)
# Fetching page 131 (offset 3,250,000)... Received 25,000 rows (total so far: 3,275,000)
# Fetching page 132 (offset 3,275,000)... Received 25,000 rows (total so far: 3,300,000)
# Fetching page 133 (offset 3,300,000)... Received 25,000 rows (total so far: 3,325,000)
# Fetching page 134 (offset 3,325,000)... Received 25,000 rows (total so far: 3,350,000)
# Fetching page 135 (offset 3,350,000)... Received 25,000 rows (total so far: 3,375,000)
# Fetching page 136 (offset 3,375,000)... Received 25,000 rows (total so far: 3,400,000)
# Fetching page 137 (offset 3,400,000)... Received 25,000 rows (total so far: 3,425,000)
# Fetching page 138 (offset 3,425,000)... Received 25,000 rows (total so far: 3,450,000)
# Fetching page 139 (offset 3,450,000)... Received 8,320 rows (total so far: 3,458,320)
# Last page reached.
# Snapshot date (UTC): 2025-11-17 05:35:13 UTC
# Total rows fetched: 3458320
# DataFrame shape: (3458320, 41)
# Columns: ['unique_key', 'created_date', 'closed_date', 'agency', 'agency_name', 'complaint_type', 'descriptor', 'location_type', 'incident_zip', 'incident_address', 'street_name', 'cross_street_1', 'cross_street_2', 'intersection_street_1', 'intersection_street_2', 'address_type', 'city', 'landmark', 'status', 'resolution_description', 'resolution_action_updated_date', 'community_board', 'bbl', 'borough', 'x_coordinate_state_plane', 'y_coordinate_state_plane', 'open_data_channel_type', 'park_facility_name', 'park_borough', 'latitude', 'longitude', 'location', 'facility_type', 'bridge_highway_name', 'bridge_highway_segment', 'taxi_pick_up_location', 'vehicle_type', 'bridge_highway_direction', 'road_ramp', 'taxi_company_borough', 'due_date']
#
# First few rows:
#
# Raw data saved to: /Users/sagorika/Documents/HCDS/Final Project/A7/data/raw/nyc311_2024_raw.parquet
# PosixPath('/Users/sagorika/Documents/HCDS/Final Project/A7/data/raw/nyc311_2024_raw.parquet')

# %% [markdown]
# The next cell just outputs first few rows of the dataframe

# %%
print(df_raw.head().to_string())
# Out:
#   unique_key             created_date              closed_date agency                              agency_name     complaint_type descriptor               location_type incident_zip            incident_address             street_name     cross_street_1  cross_street_2 intersection_street_1 intersection_street_2 address_type           city                landmark  status                                                                                                                                                                              resolution_description resolution_action_updated_date   community_board         bbl        borough x_coordinate_state_plane y_coordinate_state_plane open_data_channel_type park_facility_name   park_borough            latitude           longitude                                                                                                                                       location facility_type bridge_highway_name bridge_highway_segment taxi_pick_up_location vehicle_type bridge_highway_direction road_ramp taxi_company_borough due_date
# 0   59898042  2024-01-01T00:00:00.000  2024-01-02T09:24:45.000  DOHMH  Department of Health and Mental Hygiene     Food Poisoning     1 or 2  Restaurant/Bar/Deli/Bakery        10462      711 MORRIS PARK AVENUE      MORRIS PARK AVENUE  WHITE PLAINS ROAD     HUNT AVENUE     WHITE PLAINS ROAD           HUNT AVENUE      ADDRESS          BRONX      MORRIS PARK AVENUE  Closed  The Department of Health and Mental Hygiene has determined that the reported incident is isolated.  The establishment will be inspected according to its normal schedule for sanitary inspections.        2024-01-02T09:24:45.000          11 BRONX  2040500001          BRONX                  1021437                   247286                 ONLINE        Unspecified          BRONX   40.84533975748463  -73.86559379953668   {'latitude': '40.84533975748463', 'longitude': '-73.86559379953668', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}           NaN                 NaN                    NaN                   NaN          NaN                      NaN       NaN                  NaN      NaN
# 1   59896272  2024-01-01T00:00:00.000  2024-01-02T00:00:01.000  DOHMH  Department of Health and Mental Hygiene     Food Poisoning     1 or 2  Restaurant/Bar/Deli/Bakery        11211  145 GRAND STREET EXTENSION  GRAND STREET EXTENSION     SOUTH 2 STREET     KEAP STREET     SOUTH    2 STREET           KEAP STREET      ADDRESS       BROOKLYN  GRAND STREET EXTENSION  Closed  The Department of Health and Mental Hygiene has determined that the reported incident is isolated.  The establishment will be inspected according to its normal schedule for sanitary inspections.        2024-01-11T10:04:21.000       01 BROOKLYN  3024110017       BROOKLYN                   996989                   198198                 ONLINE        Unspecified       BROOKLYN  40.710675306389646    -73.954050047883    {'latitude': '40.710675306389646', 'longitude': '-73.954050047883', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}           NaN                 NaN                    NaN                   NaN          NaN                      NaN       NaN                  NaN      NaN
# 2   59894610  2024-01-01T00:00:00.000  2024-01-02T09:46:32.000  DOHMH  Department of Health and Mental Hygiene     Food Poisoning     1 or 2  Restaurant/Bar/Deli/Bakery        10304           7 NAVY PIER COURT         NAVY PIER COURT       FRONT STREET        DEAD END          FRONT STREET              DEAD END      ADDRESS  STATEN ISLAND         NAVY PIER COURT  Closed                             The NYC Health Department (DOHMH) found a service request already exists for the same location. This request has been closed. DOHMH is addressing the original request.        2024-12-27T12:00:00.000  01 STATEN ISLAND  5004877501  STATEN ISLAND                   963602                   168384                 ONLINE        Unspecified  STATEN ISLAND  40.628827651071944   -74.0743866176229   {'latitude': '40.628827651071944', 'longitude': '-74.0743866176229', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}           NaN                 NaN                    NaN                   NaN          NaN                      NaN       NaN                  NaN      NaN
# 3   59899838  2024-01-01T00:00:00.000  2024-01-02T09:42:25.000  DOHMH  Department of Health and Mental Hygiene     Food Poisoning     1 or 2  Restaurant/Bar/Deli/Bakery        10022               1069 1 AVENUE                1 AVENUE     EAST 58 STREET  EAST 59 STREET      EAST   58 STREET      EAST   59 STREET      ADDRESS       NEW YORK                1 AVENUE  Closed  The Department of Health and Mental Hygiene has determined that the reported incident is isolated.  The establishment will be inspected according to its normal schedule for sanitary inspections.        2024-01-11T14:23:12.000      06 MANHATTAN  1013510025      MANHATTAN                   994697                   215873                 ONLINE        Unspecified      MANHATTAN  40.759191822016476  -73.96228991313669  {'latitude': '40.759191822016476', 'longitude': '-73.96228991313669', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}           NaN                 NaN                    NaN                   NaN          NaN                      NaN       NaN                  NaN      NaN
# 4   59887043  2024-01-01T00:00:20.000  2024-01-01T00:41:01.000   NYPD          New York City Police Department  Illegal Fireworks        N/A             Street/Sidewalk        11228  7223 FORT HAMILTON PARKWAY   FORT HAMILTON PARKWAY          72 STREET       73 STREET             72 STREET             73 STREET      ADDRESS       BROOKLYN   FORT HAMILTON PARKWAY  Closed                                                             The Police Department responded to the complaint and with the information available observed no evidence of the violation at that time.        2024-01-01T00:41:04.000       10 BROOKLYN  3059130001       BROOKLYN                   980226                   167744                 ONLINE        Unspecified       BROOKLYN   40.62709413549678  -74.01449651007135   {'latitude': '40.62709413549678', 'longitude': '-74.01449651007135', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}           NaN                 NaN                    NaN                   NaN          NaN                      NaN       NaN                  NaN      NaN

# %% [markdown]
# ## Loading raw data from disk
#
# The next cell sets up the project paths and loads the raw data from the saved parquet file. We need to use this cell instead of the API fetch cell if we've already downloaded the data.

# %%
from pathlib import Path
import pandas as pd
import sys

PROJECT_ROOT = Path('..').resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

# loading raw data from parquet file
raw_path = PROJECT_ROOT / 'data' / 'raw' / 'nyc311_2024_raw.parquet'
if raw_path.exists():
    print(f"Loading raw data from {raw_path}...")
    df_raw = pd.read_parquet(raw_path)
    print(f"Loaded {len(df_raw):,} rows")
    print(f"DataFrame shape: {df_raw.shape}")
else:
    print(f"Raw data file not found at {raw_path}")
    print("Please run the data fetching cell (Cell 4) first to download the data.")
# Out:
# Loading raw data from /Users/sagorika/Documents/HCDS/Final Project/A7/data/raw/nyc311_2024_raw.parquet...
# Loaded 3,458,320 rows
# DataFrame shape: (3458320, 41)

# %% [markdown]
# ## Examining data types and structure
#
# The next cell checks the data types of each column and shows basic information about missing values. This helps us understand what cleaning steps are needed.

# %%
print("Data types:")
print(df_raw.dtypes)
print("\n" + "="*80)
print("\nMissing values per column:")
missing = df_raw.isnull().sum()
missing_pct = (missing / len(df_raw) * 100).round(2)
missing_df = pd.DataFrame({
    'Missing Count': missing,
    'Missing %': missing_pct
})
print(missing_df[missing_df['Missing Count'] > 0].sort_values('Missing Count', ascending=False))
print("\n" + "="*80)
print(f"\nTotal rows: {len(df_raw):,}")
print(f"Key columns for analysis:")
print(f"  - created_date: {df_raw['created_date'].isnull().sum():,} missing")
print(f"  - closed_date: {df_raw['closed_date'].isnull().sum():,} missing")
print(f"  - borough: {df_raw['borough'].isnull().sum():,} missing")
print(f"  - open_data_channel_type: {df_raw['open_data_channel_type'].isnull().sum():,} missing")
print(f"  - complaint_type: {df_raw['complaint_type'].isnull().sum():,} missing")
# Out:
# Data types:
# unique_key                        object
# created_date                      object
# closed_date                       object
# agency                            object
# agency_name                       object
# complaint_type                    object
# descriptor                        object
# location_type                     object
# incident_zip                      object
# incident_address                  object
# street_name                       object
# cross_street_1                    object
# cross_street_2                    object
# intersection_street_1             object
# intersection_street_2             object
# address_type                      object
# city                              object
# landmark                          object
# status                            object
# resolution_description            object
# resolution_action_updated_date    object
# community_board                   object
# bbl                               object
# borough                           object
# x_coordinate_state_plane          object
# y_coordinate_state_plane          object
# open_data_channel_type            object
# park_facility_name                object
# park_borough                      object
# latitude                          object
# longitude                         object
# location                          object
# facility_type                     object
# bridge_highway_name               object
# bridge_highway_segment            object
# taxi_pick_up_location             object
# vehicle_type                      object
# bridge_highway_direction          object
# road_ramp                         object
# taxi_company_borough              object
# due_date                          object
# dtype: object
#
# ================================================================================
#
# Missing values per column:
#                                 Missing Count  Missing %
# taxi_company_borough                  3456136      99.94
# road_ramp                             3449815      99.75
# bridge_highway_direction              3446777      99.67
# due_date                              3438698      99.43
# bridge_highway_name                   3437138      99.39
# bridge_highway_segment                3437135      99.39
# taxi_pick_up_location                 3421051      98.92
# vehicle_type                          3296754      95.33
# facility_type                         3186329      92.14
# landmark                              1369332      39.60
# intersection_street_1                 1129535      32.66
# intersection_street_2                 1128069      32.62
# cross_street_1                         985565      28.50
# cross_street_2                         985329      28.49
# location_type                          416725      12.05
# bbl                                    377871      10.93
# city                                   161537       4.67
# street_name                            120305       3.48
# incident_address                       120185       3.48
# closed_date                             68971       1.99
# latitude                                53580       1.55
# longitude                               53580       1.55
# location                                53580       1.55
# x_coordinate_state_plane                53557       1.55
# y_coordinate_state_plane                53418       1.54
# resolution_description                  43428       1.26
# descriptor                              39524       1.14
# incident_zip                            34364       0.99
# resolution_action_updated_date          14481       0.42
# address_type                            14131       0.41
#
# ================================================================================
#
# Total rows: 3,458,320
# Key columns for analysis:
#   - created_date: 0 missing
#   - closed_date: 68,971 missing
#   - borough: 0 missing
#   - open_data_channel_type: 0 missing
#   - complaint_type: 0 missing

# %% [markdown]
# ## Cleaning the data
#
# The next cell imports the cleaning functions and applies all cleaning steps to prepare the data for analysis. This includes converting dates, computing response times, filtering invalid rows, standardizing channel types, removing duplicates, winsorizing outliers, and selecting top complaint types.

# %%
import sys, pandas as pd
from pathlib import Path

PROJECT_ROOT = Path('..').resolve()
sys.path.insert(0, str(PROJECT_ROOT))
from src.nyc311_cleaning import clean_nyc311_data

# keeping top 10 complaint types by default for reliable comparisons
df_clean = clean_nyc311_data(
    df_raw,
    winsorize_percentile=99.0,
    top_complaint_types=10,
)

print("Cleaned data summary:")
print(f"Shape: {df_clean.shape}")
print(f"\nResponse time statistics (days):")
print(df_clean['response_time_days'].describe())
print(f"\nChannel distribution:")
print(df_clean['open_data_channel_type'].value_counts())
print(f"\nBorough distribution:")
print(df_clean['borough'].value_counts())
# Out:
# Starting data cleaning process...
# Initial row count: 3,458,320
#
# Step 1: Converting dates to datetime...
# Step 2: Computing response time...
# Step 3: Filtering invalid rows...
# Removed 128,060 rows with missing required fields or invalid response times.
# Remaining rows: 3,330,260
# Step 4: Standardizing channel types...
#
# Channel type distribution after standardization:
# open_data_channel_type
# Web      1586605
# Phone    1032985
# App       710670
# Name: count, dtype: int64
# Step 5: Removing duplicates...
#
# Removed 2 duplicate rows based on unique_key.
# Remaining rows: 3,330,258
# Step 6: Winsorizing response times at 99.0th percentile...
#
# Winsorized 33,303 values at 99.0th percentile (273.21 days).
# Step 7: Selecting top complaint types...
#
# Filtered to top complaint types:
#   Kept 10 complaint types
#   Removed 1,460,942 rows from other complaint types
#   Remaining rows: 1,869,316
#
# Top complaint types:
#   - Illegal Parking: 505,732 records
#   - Noise - Residential: 379,252 records
#   - HEAT/HOT WATER: 261,748 records
#   - Blocked Driveway: 170,190 records
#   - Noise - Street/Sidewalk: 162,997 records
#   - UNSANITARY CONDITION: 120,699 records
#   - Abandoned Vehicle: 70,326 records
#   - Noise - Commercial: 68,334 records
#   - PLUMBING: 65,767 records
#   - PAINT/PLASTER: 64,271 records
#
# Cleaning complete!
# Final row count: 1,869,316
# Cleaned data summary:
# Shape: (1869316, 42)
#
# Response time statistics (days):
# count    1.869316e+06
# mean     2.896917e+00
# std      1.316524e+01
# min      3.472222e-05
# 25%      2.879630e-02
# 50%      9.376157e-02
# 75%      8.103385e-01
# max      2.732056e+02
# Name: response_time_days, dtype: float64
#
# Channel distribution:
# open_data_channel_type
# Web      758634
# App      561853
# Phone    548829
# Name: count, dtype: int64
#
# Borough distribution:
# borough
# BROOKLYN         580861
# BRONX            486025
# QUEENS           428697
# MANHATTAN        329076
# STATEN ISLAND     44594
# Unspecified          63
# Name: count, dtype: int64

# %% [markdown]
# ## Saving cleaned data
#
# The next cell saves the cleaned dataset to the processed data folder for use in the main analysis notebook.

# %%
processed_dir = PROJECT_ROOT / 'data' / 'processed'
processed_dir.mkdir(parents=True, exist_ok=True)

clean_path = processed_dir / 'nyc311_2024_cleaned.parquet'
df_clean.to_parquet(clean_path, index=False)

print(f"Cleaned data saved to: {clean_path}")
print(f"Final dataset: {len(df_clean):,} rows, {len(df_clean.columns)} columns")
clean_path
# Out:
# Cleaned data saved to: /Users/sagorika/Documents/HCDS/Final Project/A7/data/processed/nyc311_2024_cleaned.parquet
# Final dataset: 1,869,316 rows, 42 columns
# PosixPath('/Users/sagorika/Documents/HCDS/Final Project/A7/data/processed/nyc311_2024_cleaned.parquet')
